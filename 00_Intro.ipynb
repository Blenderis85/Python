# %%
import cowsay

cowsay.cow("Good Mooooorning!")
# Out:
#   _________________
# | Good Mooooorning! |
# ...
#                  \
#                   \
#                     ^__^
#                     (oo)\_______
#                     (__)\       )\/\
#                         ||----w |
#                         ||     ||

# %%
import sys

print(sys.version)
# Out:
# 3.14.6 (tags/v3.14.6:c63aec6, Jun 10 2026, 10:26:10) [MSC v.1944 64 bit (AMD64)]

# %%
print("Hello, World!")
# Out:
# Hello, World!
