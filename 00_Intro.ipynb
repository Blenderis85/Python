# %%
import cowsay

cowsay.cow("Good Mooooorning!")
# Out:
#   _________________
# | Good Mooooorning! |
# ...
#                  \
#                   \
#                     ^__^
#                     (oo)\_______
#                     (__)\       )\/\
#                         ||----w |
#                         ||     ||
