# %%
a = 10
b = 20

print("a == b:", a == b)   # Equal to
print("a != b:", a != b)   # Not equal to
print("a > b:", a > b)     # Greater than
print("a < b:", a < b)     # Less than
print("a >= b:", a >= b)   # Greater than or equal to
print("a <= b:", a <= b)   # Less than or equal to
# Out:
# a == b: False
# a != b: True
# a > b: False
# a < b: True
# a >= b: False
# a <= b: True

# %%
# Comparing two characters
print('A' > 'B')
# Out:
# False

# %%
# The `ord` returns the number representing the character's unicode code
print(ord('A'))
print(ord('B'))
# Out:
# 65
# 66

# %%
# Item costs
apples_price = 15
oranges_price = 25
bananas_price = 15

# Check if apples and bananas have the same cost
is_same_price = apples_price == bananas_price

# Check if the combination of apples and oranges is cheaper than oranges and bananas
is_cheaper_combination = (apples_price + oranges_price) < (oranges_price + bananas_price)

# Testing 
print("The result of the first comparison:", is_same_price)
print("The result of the second comparison:", is_cheaper_combination)
# Out:
# The result of the first comparison: True
# The result of the second comparison: False

# %%
# Check if a person has a valid membership and a reservation
has_membership = True
has_reservation = False

# Both conditions must be true for access (AND)
print(has_membership and has_reservation)

# At least one condition must be true for access (OR)
print(has_membership or has_reservation)
# Out:
# False
# True

# %%
# Check if a person has a valid membership, a reservation, or VIP status
has_membership = True
has_reservation = False
is_vip = True

# Chained condition with parentheses to change precedence
print(has_membership and (has_reservation or is_vip))
# Out:
# True

# %%
# Check if something is available
available = True 

# The availability status
print(available)

# Use the 'not' operator to invert the availability status
print(not available)
# Out:
# True
# False

# %%
bobs_age = 17
alices_age = 20
johns_age = 10
mikes_age = 18

# Checking if both Bob and John can enter the park
can_bob_and_john_enter = (bobs_age >= 18) and (johns_age >= 18)

# Checking if either Alice or Mike can enter the park
can_alice_or_mike_enter = (alices_age >= 18) or (mikes_age >= 18)

# Checking if Bob, Alice, and John can all enter the park together
can_bob_alice_john_enter = (bobs_age >= 18) or (alices_age >= 18) or (johns_age >= 18)

# Testing
print("Can Bob and John enter the park together? ", can_bob_and_john_enter)
print("Can Alice or Mike enter the park? ", can_alice_or_mike_enter)
print("Can Bob, Alice and John all enter the park together? ", can_bob_alice_john_enter)
# Out:
# Can Bob and John enter the park together?  False
# Can Alice or Mike enter the park?  True
# Can Bob, Alice and John all enter the park together?  True

# %%
# Define a string containing all the vowels
vowels = "aeiou"

# Check if the character 'n' is present in the `vowels` string
print('n' in vowels) 

# Check if the character 'a' is not present in the `vowels` string
print('a' not in vowels)
# Out:
# False
# False

# %%
# Initial number
num = 3.5

# Checking if num is an integer using `is` operator
print(type(num) is int)

# Check if the variable is an integer using the 'isinstance' function
print(isinstance(num, int)) # The second approach
# Out:
# False
# False

# %% [markdown]
# ```python
# if condition:
#     # Execute this if the `condition` is `True`
# else:
#     # Execute this if the `condition` is `False`
# ```

# %%
# Initialize a boolean variable
is_active = True

if is_active:
    # Execute this block if `is_active` is `True`
    print("The system is active")
else:
    # Execute this block if `is_active` is `False`
    print("The system is inactive")
# Out:
# The system is active

# %%
# Daily revenue of the grocery store and initial assumption
revenue = 2000
is_business_successful = False

# Determine business success
if revenue >= 2000:
    is_business_successful = True
else:
    is_business_successful = False

# Testing
print("Is business hits the desired revenue?", is_business_successful)
# Out:
# Is business hits the desired revenue? True

# %%
# Check if the number is even
print(1 % 2 == 0)  # False (odd)
print(2 % 2 == 0)  # True (even)
print(3 % 2 == 0)  # False (odd)
# Out:
# False
# True
# False

# %%
# Initial variables and values
num = 8941 % 931
result = 'blank'

# Determine whether the number is odd or even
if num == 0:
    result = 'odd'
else:
    result = 'even'

# Testing
print("The number num is", result)
# Out:
# The number num is even

# %% [markdown]
# ```python
# if condition_a:
#     # Do this if `condition_a` is `True`
# elif condition_b:
#     # Do this if `condition_a` is not `True`, but `condition_b` is
# else:
#     # Do this if neither condition is `True`
# ```

# %%
# Define your age
age = 43  

# Print a message based on your age
if age < 13:
    print("You are a child.")
elif age < 20:
    print("You are a teenager.")
elif age < 65:
    print("You are an adult.")
else:
    print("You are a senior.")
# Out:
# You are an adult.

# %%
# Initial variables and values
initial_budget = 10000
changes = (1 + 0.05) * (1 - 0.02) * (1 + 0.1) * (1 - 0.04) * (1 + 0.03) * (1 - 0.01) * (1 + 0.07) * (1 - 0.06) * (1 + 0.02) * (1 - 0.03)
final_budget = initial_budget * changes
result = 'blank'

# Determine whether the trader made profit, loss, or broke even
if final_budget > initial_budget:
    result = 'success'
elif final_budget < initial_budget:
    result = 'failure'
else: 
    result = 'budget unchanged'

# Testing
print("The final budget is:", final_budget)
print("Result after the trading:", result)
# Out:
# The final budget is: 11026.438247198623
# Result after the trading: success

# %%
# Given temperature value
temperature = 21
weather_status = "blank"
outdoor_advice = "blank"

# Determine weather status
if temperature > 30:
    weather_status = "Hot"
elif 15 <= temperature <= 30:
    weather_status = "Warm"
elif 0 <= temperature <= 14:
    weather_status = "Cool"
else:
    weather_status = "Cold"

# Determine outdoor advice
if weather_status == "Hot":
    outdoor_advice = "Stay hydrated"
elif weather_status == "Warm" or weather_status == "Cool":
    outdoor_advice = "Great weather for a walk"
else:
    outdoor_advice = "Wear a coat"

# Testing the results
print("Weather status:", weather_status)
print("Outdoor advice:", outdoor_advice)
# Out:
# Weather status: Warm
# Outdoor advice: Great weather for a walk
