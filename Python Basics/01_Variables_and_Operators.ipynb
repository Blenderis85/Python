# %%
# Variable called `expenses` with value `1200`
expenses = 1200

# %%
# Monthly expenses amount in dollars
monthly_expenses = 1200

# Discount rate as a decimal (20%)
discount_rate = 0.2

# Calculated total expenses after applying the discount
total_expenses = monthly_expenses * (1 - discount_rate)
print(total_expenses)
# Out:
# 960.0

# %%
# Snake_case is preferred in Python because it improves readability
each_word_in_lowercase_and_separated_with_underscores = 1000

# %%
# Number of classes and students per class
classes = 6
students = 45

# Calculate total number of students
total_students = classes * students

# Calculate total number of classes
total_classes = total_students / 27

# Testing
print("Number of students:", total_students)
print("Number of groups:", total_classes)
# Out:
# Number of students: 270
# Number of groups: 10.0

# %%
# Text
text_var = "Hello, World!"  # `str`

# Numeric
int_var = 42                # `int`
float_var = 3.14            # `float`
complex_var = 2 + 3j        # `complex`

# Boolean
bool_var = True             # `bool`

# Check variable type
print(type(text_var))
# Out:
# <class 'str'>

# %%
# Variables
int_num = 11
real_num = 16.83

# Show original and converted values
# int() removes the decimal part
print(int_num, float(int_num))
print(real_num, int(real_num))
# Out:
# 11 11.0
# 16.83 16

# %%
# Perform division of two integers
division = 25 / 5

# The result of the division and its type
print(division, type(division))
# Out:
# 5.0 <class 'float'>

# %%
# Distance in kilometers
distance_in_kilometers = 4677.4

# Convert distance to miles and store in `distance_in_miles`
distance_in_miles = distance_in_kilometers / 1.609

# Convert variable type to int and store in `int_distance_in_miles`
int_distance_in_miles = int(distance_in_miles)

# Testing
print("San Francisco - New York distance (float): ", distance_in_miles, "mi")
print("San Francisco - New York distance (int): ", int_distance_in_miles, "mi")
# Out:
# San Francisco - New York distance (float):  2907.0229956494713 mi
# San Francisco - New York distance (int):  2907 mi

# %%
# Save string within variable
language = 'Python'

# Output string
print(language)
# Out:
# Python

# %%
# Assigning a numeric value as a string to the variable 'hour'
hour = '16'

# Printing the value stored in 'hour'
print(hour)
# Out:
# 16

# %%
# Use `\` to escape quotes inside string
quote = 'She said, \"It\'s a wonderful day!\"'

# Printing the `quote`
print(quote)
# Out:
# She said, "It's a wonderful day!"

# %%
# The string of digits
word = "codefinity"

# Access the character at index 1 (second character)
print(word[1])
# Out:
# o

# %%
# The string of digits
word = "codefinity"

# Access the characters at index -1 and -9 (first and last ones)
print(word[-1], word[-10])
# Out:
# y c

# %%
# Initial strings
platform_name = "codefinity"
greeting_message = "How are you"

# Slice strings to extract substrings
# Spaces count as characters and have their own indices
print(platform_name[0:4], platform_name[6:10])
print(greeting_message[2:5], greeting_message[6:11])
# Out:
# code nity
# w a e you

# %%
# Initial string to demonstrate string manipulation
sample_text = "This is a string for learning"

# Extracting the first character from the string
first_char = sample_text[0]

# Extracting the last character from the string
last_char = sample_text[-1]

# Extracting a highlighted word from the string
highlighted_word = sample_text[-12:-9]

# Testing
print("The first char of the string: ", first_char)
print("The last char of the string: ", last_char)
print("The highlighted word from the string: ", highlighted_word)
# Out:
# The first char of the string:  T
# The last char of the string:  g
# The highlighted word from the string:  for

# %%
# Article and word
article = "The"
country = "Netherlands"

# Concatenate without a space
print(article + country)

# Concatenate with a space between
print(article + " " + country) # Add blank space between
# Out:
# TheNetherlands
# The Netherlands

# %%
# Variables to store the greeting message and user ID
greeting = "Welcome, user #"
user_id = 42

# Attempting direct concatenation (will raise an error)
# print(greeting + user_id)

# Correct way: Convert the number to a string
print(greeting + str(user_id))
# Out:
# Welcome, user #42
