# %%
print("Some message")
# Out:
# Some message

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
# The `print()` statement below won't be executed
# print('This is a commented line')
print('This text will be printed')
# Out:
# This text will be printed

# %%
print("Hello, World!")
print("Welcome to Python programming.")
# print("Will this line be displayed?")
# Out:
# Hello, World!
# Welcome to Python programming.

# %%
# Addition
print(1039 + 948)

# Subtraction
print(10484 - 9274)

# Multiplication
print(116 * 99)

# Division
print(95873 / 472)
# Out:
# 1987
# 1210
# 11484
# 203.12076271186442

# %%
print(25 + 100 * 5)
# Out:
# 525

# %%
# Calculate addition
print(2580 + 198)

# Calculate multiplication
print(23 * 42)

# Calculate division
print(1512 / 27)
# Out:
# 2778
# 966
# 56.0

# %%
# Floor division
print(18 // 4)

# Remainder of the division
print(18 % 4)

# Raising to the power
print(18 ** 4)
# Out:
# 4
# 2
# 104976

# %%
# Calculate the integer part of division
print(250 // 6)

# Calculate the remainder of division
print(250 % 6)
# Out:
# 41
# 4

# %%
print("Shopping Receipt")
print("-----------------------")
print("Item 1: $", 162 * 1.2)  # Price per weight
print("Item 2: $", 25 - 3)     # Discounted price
print("-----------------------")
print("Subtotal: $", (162 * 1.2) + (25 - 3))
print("Tax (8%): $", ((162 * 1.2) + (25 - 3)) * 0.08)
print("-----------------------")
print("Thank you for shopping!")
# Out:
# Shopping Receipt
# -----------------------
# Item 1: $ 194.4
# Item 2: $ 22
# -----------------------
# Subtotal: $ 216.4
# Tax (8%): $ 17.312
# -----------------------
# Thank you for shopping!
